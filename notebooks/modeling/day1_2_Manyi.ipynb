# %% [markdown]
# ## feature engineering and dataset cleaning

# %%
import numpy as np
import pandas as pd
df = pd.read_csv('youtube_cleaned_success_only.csv')
df.head(2)
# Out:
#       video_id                                              title     channel  \
# 0  F8ZTXYOPRZ4     Do your baby’s hair 🤣#greys #greysanatomy #fyp  Andy Huang
# 1  bZVQcBgjfSI  XYL ARP556+Black Bear Tracer.Who needs this fo...        LKCJ
#
#                  channel_id             published    views   likes  \
# 0  UCy06srAhwzLdsPBC6CiR96A  2025-02-18T06:00:09Z  7378507  438016
# 1  UC_bPnE6C8ucaq7JHPKlaf-Q  2025-02-25T14:50:30Z  2550039   65566
#
#                                       thumbnail_url  category_id  subscribers  \
# 0  https://i.ytimg.com/vi/F8ZTXYOPRZ4/hqdefault.jpg           22        16000
# 1  https://i.ytimg.com/vi/bZVQcBgjfSI/hqdefault.jpg           22      5680000
#
#   region Source.Name
# 0     CA         NaN
# 1     CA         NaN

# %%
# 3. Convert that column to datetime
df['published'] = pd.to_datetime(df['published'], format="%Y-%m-%dT%H:%M:%SZ", errors='coerce')

# 4. Extract the date if you need it
df['publish_date'] = df['published'].dt.date

# 5. Extract the hour (0–23) directly
df['publish_hour'] = df['published'].dt.hour

# 6. (Optional) If you really want a time object too:
df['publish_time'] = df['published'].dt.time

# 7. Drop the old Source.Name column
df.drop('Source.Name', axis=1, inplace=True)

df.head()
# Out:
#       video_id                                              title  \
# 0  F8ZTXYOPRZ4     Do your baby’s hair 🤣#greys #greysanatomy #fyp
# 1  bZVQcBgjfSI  XYL ARP556+Black Bear Tracer.Who needs this fo...
# 2  WPc3qG3kZnw  How to terminate a Cat7 field termination with...
# 3  mvWE3inpe6Y  If you want to eat chicken wings, you can try ...
# 4  mle65DevJQo     Peppa Pig’s New Red Bed | Kids Story Animation
#
#                             channel                channel_id  \
# 0                        Andy Huang  UCy06srAhwzLdsPBC6CiR96A
# 1                              LKCJ  UC_bPnE6C8ucaq7JHPKlaf-Q
# 2                       HY CONNECT   UCYxXK5KWL_Ta6jZ4yzFGVhQ
# 3  Chinese Cuisine Official channel  UCY6zyw7X3tMYAN5ZxbrNyog
# 4                          Mushroom  UCcYKDKMq3KMxcpdF9bteFFQ
#
#             published     views   likes  \
# 0 2025-02-18 06:00:09   7378507  438016
# 1 2025-02-25 14:50:30   2550039   65566
# 2 2025-02-13 08:33:21   1989137   22551
# 3 2025-02-11 12:01:13    173074    3513
# 4 2025-02-12 04:00:28  13451466  585370
#
#                                       thumbnail_url  category_id  subscribers  \
# 0  https://i.ytimg.com/vi/F8ZTXYOPRZ4/hqdefault.jpg           22        16000
# 1  https://i.ytimg.com/vi/bZVQcBgjfSI/hqdefault.jpg           22      5680000
# 2  https://i.ytimg.com/vi/WPc3qG3kZnw/hqdefault.jpg           22        12800
# 3  https://i.ytimg.com/vi/mvWE3inpe6Y/hqdefault.jpg           26        67000
# 4  https://i.ytimg.com/vi/mle65DevJQo/hqdefault.jpg            1      4600000
#
#   region publish_date  publish_hour publish_time
# 0     CA   2025-02-18           6.0     06:00:09
# 1     CA   2025-02-25          14.0     14:50:30
# 2     CA   2025-02-13           8.0     08:33:21
# 3     CA   2025-02-11          12.0     12:01:13
# 4     CA   2025-02-12           4.0     04:00:28

# %%
df = df.dropna(subset=['published']).reset_index(drop=True)

# %%
df.isnull().sum()
# Out:
# video_id         0
# title            0
# channel          0
# channel_id       0
# published        0
# views            0
# likes            0
# thumbnail_url    0
# category_id      0
# subscribers      0
# region           0
# publish_date     0
# publish_hour     0
# publish_time     0
# dtype: int64

# %%
import pandas as pd

# 1. Make sure publish_date is datetime64
df['publish_date'] = pd.to_datetime(df['publish_date'])

# 2. Extract the day name (Monday, Tuesday, …)
df['day_of_week'] = df['publish_date'].dt.day_name()

# %%
# 创建一个新列：weekday (工作日) 或 weekend (周末)
df['day_type'] = df['publish_date'].apply(lambda x: 'weekday' if x.weekday() < 5 else 'weekend')
# 定义时间段分类函数
def classify_time_of_day(t):
    hour = t.hour
    if 7 <= hour < 12:
        return 'morning'     # 早上
    elif 12 <= hour < 17:
        return 'afternoon'   # 下午
    elif 17 <= hour < 22:
        return 'evening'     # 晚上
    elif 22 <= hour < 24:
        return 'late evening'     # 晚上
    else:
        return 'other'    # 凌晨（包含 22点 到 第二天早上5点）

# 应用到 publish_time 列
df['time_of_day'] = df['publish_time'].apply(classify_time_of_day)
df
# Out:
#          video_id                                              title  \
# 0     F8ZTXYOPRZ4     Do your baby’s hair 🤣#greys #greysanatomy #fyp
# 1     bZVQcBgjfSI  XYL ARP556+Black Bear Tracer.Who needs this fo...
# 2     WPc3qG3kZnw  How to terminate a Cat7 field termination with...
# 3     mvWE3inpe6Y  If you want to eat chicken wings, you can try ...
# 4     mle65DevJQo     Peppa Pig’s New Red Bed | Kids Story Animation
# ...           ...                                                ...
# 9903  3DmX7mEp2gY  Ammayi Garu - Quick Recap - 4 - Apuroopa, Raju...
# 9904  IHvJWhQhjos  Nindu Noorella Saavasam - Quick Recap - 11 - M...
# 9905  2R3fRhGFdIw  Meenakshi Ponnunga - Quick Recap - 26 - Meenak...
# 9906  Adpmxe2Us4Y  Meenakshi Ponnunga - Quick Recap - 15 - Meenak...
# 9907  _1qOJ5mw3xg  Prema Entha Maduram - Quick Recap - 17 - Anu, ...
#
#                                channel                channel_id  \
# 0                           Andy Huang  UCy06srAhwzLdsPBC6CiR96A
# 1                                 LKCJ  UC_bPnE6C8ucaq7JHPKlaf-Q
# 2                          HY CONNECT   UCYxXK5KWL_Ta6jZ4yzFGVhQ
# 3     Chinese Cuisine Official channel  UCY6zyw7X3tMYAN5ZxbrNyog
# 4                             Mushroom  UCcYKDKMq3KMxcpdF9bteFFQ
# ...                                ...                       ...
# 9903                        Zee Telugu  UC3PYGKK29qJ0zu-eEthHK4g
# 9904                        Zee Telugu  UC3PYGKK29qJ0zu-eEthHK4g
# 9905                         Zee Tamil  UC_wIGmvdyAQLtl-U2nHV9rg
# 9906                         Zee Tamil  UC_wIGmvdyAQLtl-U2nHV9rg
# 9907                        Zee Telugu  UC3PYGKK29qJ0zu-eEthHK4g
#
#                published     views   likes  \
# 0    2025-02-18 06:00:09   7378507  438016
# 1    2025-02-25 14:50:30   2550039   65566
# 2    2025-02-13 08:33:21   1989137   22551
# 3    2025-02-11 12:01:13    173074    3513
# 4    2025-02-12 04:00:28  13451466  585370
# ...                  ...       ...     ...
# 9903 2025-02-22 03:10:00      1377      12
# 9904 2025-02-24 03:20:00      2236      31
# 9905 2025-02-23 06:00:02       676       3
# 9906 2025-02-22 06:00:11       407       2
# 9907 2025-02-23 07:20:00      1629      25
#
#                                          thumbnail_url  category_id  \
# 0     https://i.ytimg.com/vi/F8ZTXYOPRZ4/hqdefault.jpg           22
# 1     https://i.ytimg.com/vi/bZVQcBgjfSI/hqdefault.jpg           22
# 2     https://i.ytimg.com/vi/WPc3qG3kZnw/hqdefault.jpg           22
# 3     https://i.ytimg.com/vi/mvWE3inpe6Y/hqdefault.jpg           26
# 4     https://i.ytimg.com/vi/mle65DevJQo/hqdefault.jpg            1
# ...                                                ...          ...
# 9903  https://i.ytimg.com/vi/3DmX7mEp2gY/hqdefault.jpg           24
# 9904  https://i.ytimg.com/vi/IHvJWhQhjos/hqdefault.jpg           24
# 9905  https://i.ytimg.com/vi/2R3fRhGFdIw/hqdefault.jpg           24
# 9906  https://i.ytimg.com/vi/Adpmxe2Us4Y/hqdefault.jpg           24
# 9907  https://i.ytimg.com/vi/_1qOJ5mw3xg/hqdefault.jpg           24
#
#       subscribers region publish_date  publish_hour publish_time day_of_week  \
# 0           16000     CA   2025-02-18           6.0     06:00:09     Tuesday
# 1         5680000     CA   2025-02-25          14.0     14:50:30     Tuesday
# 2           12800     CA   2025-02-13           8.0     08:33:21    Thursday
# 3           67000     CA   2025-02-11          12.0     12:01:13     Tuesday
# 4         4600000     CA   2025-02-12           4.0     04:00:28   Wednesday
# ...           ...    ...          ...           ...          ...         ...
# 9903     16600000    IND   2025-02-22           3.0     03:10:00    Saturday
# 9904     16600000    IND   2025-02-24           3.0     03:20:00      Monday
# 9905     16400000    IND   2025-02-23           6.0     06:00:02      Sunday
# 9906     16400000    IND   2025-02-22           6.0     06:00:11    Saturday
# 9907     16600000    IND   2025-02-23           7.0     07:20:00      Sunday
#
#      day_type time_of_day
# 0     weekday       other
# 1     weekday   afternoon
# 2     weekday     morning
# 3     weekday   afternoon
# 4     weekday       other
# ...       ...         ...
# 9903  weekend       other
# 9904  weekday       other
# 9905  weekend       other
# 9906  weekend       other
# 9907  weekend     morning
#
# [9908 rows x 17 columns]

# %%
df_train = df.copy()
df_train = df_train.drop(['published','title', 'channel', 'channel_id', 'publish_date','thumbnail_url', 'publish_time'], axis=1)
df_train.head()
# Out:
#       video_id     views   likes  category_id  subscribers region  \
# 0  F8ZTXYOPRZ4   7378507  438016           22        16000     CA
# 1  bZVQcBgjfSI   2550039   65566           22      5680000     CA
# 2  WPc3qG3kZnw   1989137   22551           22        12800     CA
# 3  mvWE3inpe6Y    173074    3513           26        67000     CA
# 4  mle65DevJQo  13451466  585370            1      4600000     CA
#
#    publish_hour day_of_week day_type time_of_day
# 0           6.0     Tuesday  weekday       other
# 1          14.0     Tuesday  weekday   afternoon
# 2           8.0    Thursday  weekday     morning
# 3          12.0     Tuesday  weekday   afternoon
# 4           4.0   Wednesday  weekday       other

# %%
df_train.isnull().sum()
# Out:
# video_id        0
# views           0
# likes           0
# category_id     0
# subscribers     0
# region          0
# publish_hour    0
# day_of_week     0
# day_type        0
# time_of_day     0
# dtype: int64

# %% [markdown]
# ### neural network

# %% [markdown]
# #### download package

# %%
# !pip install tensorflow
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.19.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (2.2.1)
# Collecting astunparse>=1.6.0 (from tensorflow)
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=24.3.25 (from tensorflow)
#   Downloading flatbuffers-25.2.10-py2.py3-none-any.whl.metadata (875 bytes)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow)
#   Downloading gast-0.6.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting google-pasta>=0.1.1 (from tensorflow)
#   Downloading google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting libclang>=13.0.0 (from tensorflow)
#   Downloading libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl.metadata (5.2 kB)
# Collecting opt-einsum>=2.3.2 (from tensorflow)
#   Downloading opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from tensorflow) (75.8.2)
# Requirement already satisfied: six>=1.12.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (1.17.0)
# Collecting termcolor>=1.1.0 (from tensorflow)
#   Downloading termcolor-3.0.1-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (4.13.0)
# Requirement already satisfied: wrapt>=1.11.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (1.71.0)
# Collecting tensorboard~=2.19.0 (from tensorflow)
#   Downloading tensorboard-2.19.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting keras>=3.5.0 (from tensorflow)
#   Downloading keras-3.9.2-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow) (2.1.3)
# Collecting h5py>=3.11.0 (from tensorflow)
#   Downloading h5py-3.13.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.5 kB)
# Collecting ml-dtypes<1.0.0,>=0.5.1 (from tensorflow)
#   Downloading ml_dtypes-0.5.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (21 kB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1 (from tensorflow)
#   Downloading tensorflow_io_gcs_filesystem-0.37.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (14 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/conda/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /opt/conda/lib/python3.10/site-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Collecting namex (from keras>=3.5.0->tensorflow)
#   Downloading namex-0.0.8-py3-none-any.whl.metadata (246 bytes)
# Collecting optree (from keras>=3.5.0->tensorflow)
#   Downloading optree-0.15.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (48 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow) (2025.1.31)
# Collecting markdown>=2.6.8 (from tensorboard~=2.19.0->tensorflow)
#   Downloading markdown-3.8-py3-none-any.whl.metadata (5.1 kB)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard~=2.19.0->tensorflow)
#   Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard~=2.19.0->tensorflow)
#   Downloading werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.10/site-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.10/site-packages (from rich->keras>=3.5.0->tensorflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Downloading tensorflow-2.19.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (644.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 644.8/644.8 MB 29.3 MB/s eta 0:00:0000:0100:01
# Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Downloading flatbuffers-25.2.10-py2.py3-none-any.whl (30 kB)
# Downloading gast-0.6.0-py3-none-any.whl (21 kB)
# Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Downloading h5py-3.13.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 6.8 MB/s eta 0:00:000:00:01
# Downloading keras-3.9.2-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 1.8 MB/s eta 0:00:000:00:01
# Downloading libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl (24.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.5/24.5 MB 115.2 MB/s eta 0:00:0000:01
# Downloading ml_dtypes-0.5.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 68.6 MB/s eta 0:00:00
# Downloading opt_einsum-3.4.0-py3-none-any.whl (71 kB)
# Downloading tensorboard-2.19.0-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 104.5 MB/s eta 0:00:00
# Downloading tensorflow_io_gcs_filesystem-0.37.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 101.4 MB/s eta 0:00:00
# Downloading termcolor-3.0.1-py3-none-any.whl (7.2 kB)
# Downloading markdown-3.8-py3-none-any.whl (106 kB)
# Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 105.9 MB/s eta 0:00:00
# Downloading werkzeug-3.1.3-py3-none-any.whl (224 kB)
# Downloading namex-0.0.8-py3-none-any.whl (5.8 kB)
# Downloading optree-0.15.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (397 kB)
# Installing collected packages: namex, libclang, flatbuffers, werkzeug, termcolor, tensorflow-io-gcs-filesystem, tensorboard-data-server, optree, opt-einsum, ml-dtypes, markdown, h5py, google-pasta, gast, astunparse, tensorboard, keras, tensorflow
# Successfully installed astunparse-1.6.3 flatbuffers-25.2.10 gast-0.6.0 google-pasta-0.2.0 h5py-3.13.0 keras-3.9.2 libclang-18.1.1 markdown-3.8 ml-dtypes-0.5.1 namex-0.0.8 opt-einsum-3.4.0 optree-0.15.0 tensorboard-2.19.0 tensorboard-data-server-0.7.2 tensorflow-2.19.0 tensorflow-io-gcs-filesystem-0.37.1 termcolor-3.0.1 werkzeug-3.1.3

# %% [markdown]
# #### start model

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras import Input, Model
from tensorflow.keras.layers import Flatten, Dense, Concatenate
from tensorflow.keras.preprocessing.image import load_img, img_to_array
# Out:
# 2025-04-21 19:47:08.186434: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-04-21 19:47:08.191528: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-04-21 19:47:08.205656: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745264828.229142    3517 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745264828.236376    3517 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1745264828.255481    3517 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1745264828.255507    3517 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1745264828.255509    3517 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1745264828.255511    3517 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-04-21 19:47:08.262580: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
df = df_train.copy()
df
# Out:
#          video_id     views   likes  category_id  subscribers region  \
# 0     F8ZTXYOPRZ4   7378507  438016           22        16000     CA
# 1     bZVQcBgjfSI   2550039   65566           22      5680000     CA
# 2     WPc3qG3kZnw   1989137   22551           22        12800     CA
# 3     mvWE3inpe6Y    173074    3513           26        67000     CA
# 4     mle65DevJQo  13451466  585370            1      4600000     CA
# ...           ...       ...     ...          ...          ...    ...
# 9903  3DmX7mEp2gY      1377      12           24     16600000    IND
# 9904  IHvJWhQhjos      2236      31           24     16600000    IND
# 9905  2R3fRhGFdIw       676       3           24     16400000    IND
# 9906  Adpmxe2Us4Y       407       2           24     16400000    IND
# 9907  _1qOJ5mw3xg      1629      25           24     16600000    IND
#
#       publish_hour day_of_week day_type time_of_day
# 0              6.0     Tuesday  weekday       other
# 1             14.0     Tuesday  weekday   afternoon
# 2              8.0    Thursday  weekday     morning
# 3             12.0     Tuesday  weekday   afternoon
# 4              4.0   Wednesday  weekday       other
# ...            ...         ...      ...         ...
# 9903           3.0    Saturday  weekend       other
# 9904           3.0      Monday  weekday       other
# 9905           6.0      Sunday  weekend       other
# 9906           6.0    Saturday  weekend       other
# 9907           7.0      Sunday  weekend     morning
#
# [9908 rows x 10 columns]

# %%
# 3. Build image tensor
IMG_SIZE = (128, 128)
def load_image(video_id):
    path = f'youtube_thumbnails/{video_id}.jpg'
    try:
        img = load_img(path, target_size=IMG_SIZE)
        return img_to_array(img) / 255.0
    except:
        return np.zeros((*IMG_SIZE, 3))

image_tensor = np.stack(df['video_id'].apply(load_image).values)  # shape = (N,128,128,3)

# %%
# 4. Prepare tabular features
tab_df = df.drop(columns=['video_id', 'views'])

# 把所有字符串类型的 categorical 列都进行 one-hot 编码
tab_df = pd.get_dummies(
    tab_df,
    columns=['region', 'day_of_week', 'day_type', 'time_of_day'],  # 👈 加上所有非数值列
    drop_first=True
)

scaler = StandardScaler()
X_tabular = scaler.fit_transform(tab_df)  # ✅ 现在可以标准化了

# %%
# log(1 + views) 缩放到更合理区间
y = np.log1p(df['views'].values)

# 6. Train/validation split
X_img_train, X_img_val, X_tab_train, X_tab_val, y_train, y_val = train_test_split(
    image_tensor, X_tabular, y, test_size=0.2, random_state=42
)

# %%
# 7. Build a very simple multi‑input model
#    (MODIFIED: Flatten image → Dense instead of Conv2D stack)

# Image branch
img_input = Input(shape=(128,128,3), name='image_input')
x = Flatten()(img_input)
x = Dense(32, activation='relu')(x)           # image embedding

# Tabular branch
tab_input = Input(shape=(X_tabular.shape[1],), name='tabular_input')
t = Dense(32, activation='relu')(tab_input)   # tabular embedding

# Merge & output
combined = Concatenate()([x, t])
z = Dense(16, activation='relu')(combined)
output = Dense(1, activation='linear')(z)     # regression output

# Create & compile
model = Model(inputs=[img_input, tab_input], outputs=output)
model.compile(optimizer='adam', loss='mse', metrics=['mae'])
model.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ image_input         │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_2 (Flatten) │ (None, 49152)     │          0 │ image_input[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ tabular_input       │ (None, 18)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 32)        │  1,572,896 │ flatten_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_9 (Dense)     │ (None, 32)        │        608 │ tabular_input[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 64)        │          0 │ dense_8[0][0],    │
# │ (Concatenate)       │                   │            │ dense_9[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_10 (Dense)    │ (None, 16)        │      1,040 │ concatenate_2[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_11 (Dense)    │ (None, 1)         │         17 │ dense_10[0][0]    │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,574,561 (6.01 MB)
#  Trainable params: 1,574,561 (6.01 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(
    [X_img_train, X_tab_train],
    y_train,
    validation_data=([X_img_val, X_tab_val], y_val),
    epochs=20,
    batch_size=32
)
# Out:
# Epoch 1/20
# 2025-04-21 20:20:00.352152: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 1558315008 exceeds 10% of free system memory.
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 33.9092 - mae: 4.1091 - val_loss: 14.2309 - val_mae: 2.8945
# Epoch 2/20
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 10.6283 - mae: 2.5159 - val_loss: 8.1283 - val_mae: 2.0494
# Epoch 3/20
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 5.6353 - mae: 1.7447 - val_loss: 6.6973 - val_mae: 1.7440
# Epoch 4/20
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 4.9638 - mae: 1.5521 - val_loss: 5.9461 - val_mae: 1.7132
# Epoch 5/20
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 4.5835 - mae: 1.4948 - val_loss: 5.4222 - val_mae: 1.5861
# Epoch 6/20
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 3.9254 - mae: 1.4079 - val_loss: 5.1960 - val_mae: 1.5150
# Epoch 7/20
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 3.6670 - mae: 1.3366 - val_loss: 4.5310 - val_mae: 1.4438
# Epoch 8/20
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 3.1708 - mae: 1.2654 - val_loss: 4.2394 - val_mae: 1.3262
# Epoch 9/20
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 3.1002 - mae: 1.2213 - val_loss: 4.3677 - val_mae: 1.3347
# Epoch 10/20
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 2.7782 - mae: 1.1545 - val_loss: 4.1021 - val_mae: 1.2575
# Epoch 11/20
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 2.7409 - mae: 1.1300 - val_loss: 3.6131 - val_mae: 1.2150
# Epoch 12/20
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 2.4976 - mae: 1.0758 - val_loss: 3.9200 - val_mae: 1.2181
# Epoch 13/20
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 2.4638 - mae: 1.0621 - val_loss: 3.5800 - val_mae: 1.2387
# Epoch 14/20
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 2.4689 - mae: 1.0586 - val_loss: 3.9026 - val_mae: 1.2188
# Epoch 15/20
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 2.7575 - mae: 1.1233 - val_loss: 3.5021 - val_mae: 1.1718
# Epoch 16/20
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 2.1169 - mae: 1.0014 - val_loss: 3.8109 - val_mae: 1.2195
# Epoch 17/20
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 2.4221 - mae: 1.0698 - val_loss: 4.6935 - val_mae: 1.4377
# Epoch 18/20
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 2.8924 - mae: 1.1317 - val_loss: 3.3893 - val_mae: 1.1640
# Epoch 19/20
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 2.3307 - mae: 1.0404 - val_loss: 4.0819 - val_mae: 1.2609
# Epoch 20/20
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 2.6136 - mae: 1.0839 - val_loss: 3.9318 - val_mae: 1.1766

# %% [markdown]
# ### evaluate performance

# %%
import matplotlib.pyplot as plt

# Loss (MSE) curve
plt.plot(history.history['loss'],    label='train MSE')
plt.plot(history.history['val_loss'],label='val   MSE')
plt.title("Model MSE Loss")
plt.xlabel("Epoch")
plt.ylabel("MSE")
plt.legend()
plt.show()

# MAE curve
plt.plot(history.history['mae'],     label='train MAE')
plt.plot(history.history['val_mae'], label='val   MAE')
plt.title("Model MAE")
plt.xlabel("Epoch")
plt.ylabel("MAE")
plt.legend()
plt.show()

# %%
val_mse, val_mae = model.evaluate(
    [X_img_val, X_tab_val],
    y_val,
    batch_size=32,
    verbose=1
)
print(f"Validation MSE = {val_mse:.2f}")
print(f"Validation MAE = {val_mae:.2f}")
# Out:
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0567 - mae: 1.1897
# Validation MSE = 3.93
# Validation MAE = 1.18

# %%
from sklearn.metrics import r2_score

y_pred_log = model.predict([X_img_val, X_tab_val]).flatten()
r2_log = r2_score(y_val, y_pred_log)
print(f"R² (log1p) = {r2_log:.3f}")
# Out:
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# R² (log1p) = 0.583
